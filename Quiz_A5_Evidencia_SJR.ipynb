# %% [markdown]
# <a href="https://colab.research.google.com/github/salomonjose00/Proyecto/blob/main/Quiz_A5_Evidencia_SJR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Quiz A5 // Salomón José Ramos A01382587

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib as mlp
import seaborn as sns

# %%
path = '/content/antropometria-dataset-1 (2).csv'

# %%
df = pd.read_csv(path)
df
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 3       91526     4        9                 DISTRITO FEDERAL     1    10
# 4      210939     3       21                           PUEBLA     2    19
# ...       ...   ...      ...                              ...   ...   ...
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18637  301099     1       30  VERACRUZ DE IGNACIO DE LA LLAVE     1    86
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  \
# ...

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %% [markdown]
# PREGUNTA 1

# %%
sns.boxplot(df['cintura'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
ndf = pd.pivot_table(data = df,index='desc_ent',values='edad',columns='sexo', aggfunc='median')
ndf
# Out:
# sexo                                1     2
# desc_ent
# AGUASCALIENTES                   28.5  28.0
# BAJA CALIFORNIA                  25.0  29.5
# BAJA CALIFORNIA SUR              29.0  29.0
# CAMPECHE                         33.0  30.0
# CHIAPAS                          24.0  28.0
# CHIHUAHUA                        32.0  34.0
# COAHUILA DE ZARAGOZA             26.0  33.0
# COLIMA                           30.0  34.0
# DISTRITO FEDERAL                 26.0  26.0
# DURANGO                          30.0  35.0
# GUANAJUATO                       22.0  34.0
# GUERRERO                         27.0  37.0
# HIDALGO                          26.0  35.0
# JALISCO                          30.5  36.0
# MEXICO                           20.0  28.0
# MICHOACAN DE OCAMPO              31.0  32.0
# MORELOS                          29.0  35.0
# NAYARIT                          30.0  35.0
# NUEVO LEON                       30.0  34.0
# OAXACA                           28.0  34.0
# ...

# %% [markdown]
# PREGUNTA 2

# %%
ndf.plot(kind='box')

# %%
dfp3 = pd.pivot_table(data = df,index = 'desc_ent', values= 'cadera', columns= 'sexo')
dfp3
# Out:
# sexo                                     1           2
# desc_ent
# AGUASCALIENTES                   95.384768   99.632282
# BAJA CALIFORNIA                  98.499394  101.438643
# BAJA CALIFORNIA SUR              99.918812  102.727888
# CAMPECHE                         96.502321  100.843431
# CHIAPAS                          89.872177   95.798701
# CHIHUAHUA                        96.642642  102.619935
# COAHUILA DE ZARAGOZA             96.150167  103.199670
# COLIMA                           97.162548  102.786677
# DISTRITO FEDERAL                 96.531034  104.390744
# DURANGO                          95.526667  100.465287
# GUANAJUATO                       93.238103  100.542946
# GUERRERO                         91.349440   96.751029
# HIDALGO                          92.186387   97.210698
# JALISCO                          96.254027  102.971486
# MEXICO                           93.984817   96.991339
# MICHOACAN DE OCAMPO              93.929651  100.008339
# ...

# %% [markdown]
# PREGUNTA 3

# %%
dfp3.plot(kind= 'line')

# %%
dfp4 = pd.pivot_table(data = df, index = 'desc_ent', values= 'sistol', columns= 'sexo', aggfunc='sum')
dfp4
# Out:
# sexo                                    1         2
# desc_ent
# AGUASCALIENTES                   37608.00  42565.25
# BAJA CALIFORNIA                  32240.00  35515.50
# BAJA CALIFORNIA SUR              32076.00  31207.00
# CAMPECHE                         28854.50  35136.25
# CHIAPAS                          28550.00  40385.50
# CHIHUAHUA                        32073.75  37742.75
# COAHUILA DE ZARAGOZA             36171.25  36969.25
# COLIMA                           30854.75  38381.25
# DISTRITO FEDERAL                 20036.00  24548.25
# DURANGO                          31436.75  39155.50
# GUANAJUATO                       34864.00  44234.50
# GUERRERO                         31312.00  43056.75
# HIDALGO                          22626.00  38481.25
# JALISCO                          26649.25  36332.25
# MEXICO                           21846.75  29587.00
# MICHOACAN DE OCAMPO              31250.25  40552.75
# MORELOS                          24613.25  39654.75
# ...

# %% [markdown]
# PREGUNTA 4

# %%
dfp4.plot(kind='barh')

# %%
dfp5= df.loc[:'talla']
dfp5
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 3       91526     4        9                 DISTRITO FEDERAL     1    10
# 4      210939     3       21                           PUEBLA     2    19
# ...       ...   ...      ...                              ...   ...   ...
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18637  301099     1       30  VERACRUZ DE IGNACIO DE LA LLAVE     1    86
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  \
# ...

# %% [markdown]
# PREGUNTA 5

# %%
hist= dfp5.talla.hist(bins=25)
