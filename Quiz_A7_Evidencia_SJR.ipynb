# %% [markdown]
# <a href="https://colab.research.google.com/github/salomonjose00/Proyecto/blob/main/Quiz_A7_Evidencia_SJR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Quiz A7 // Salomón José Ramos A01382587

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib as mlp
import seaborn as sns
import plotly.express as px

# %%
path = '/content/antropometria-dataset-1 (3).csv'

# %%
df = pd.read_csv(path)
df
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 3       91526     4        9                 DISTRITO FEDERAL     1    10
# 4      210939     3       21                           PUEBLA     2    19
# ...       ...   ...      ...                              ...   ...   ...
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18637  301099     1       30  VERACRUZ DE IGNACIO DE LA LLAVE     1    86
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  \
# ...

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %% [markdown]
# PREGUNTA 1

# %%
df.peso.hist(bins=15)

# %% [markdown]
# PREGUNTA 2

# %%
sns.lmplot(x='sistol', 
           y='peso', 
           hue='sexo', 
           markers=['x', 'o'],
           fit_reg=False, 
           data=df)

# %% [markdown]
# PREGUNTA 3

# %%
ehombre = df.loc[(df['sexo'] == 1)] 
dibujo = px.box(df, y="cintura")
dibujo.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# PREGUNTA 4

# %%
sns.lmplot(x='sistol', 
           y='diastol', 
           hue='sexo', 
           markers=['o', 'x'],
           fit_reg=False, 
           data=df)

# %% [markdown]
# PREGUNTA 5

# %%
hombre = df.loc[(df['sexo'] == 1)]

plt.hist(hombre['cintura'], 
         bins=25
         )
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 2.700e+01, 3.860e+02,
#         9.300e+02, 1.342e+03, 1.443e+03, 1.571e+03, 1.297e+03, 7.330e+02,
#         2.750e+02, 7.900e+01, 3.700e+01, 1.100e+01, 2.000e+00, 2.000e+00,
#         2.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.300e+01]),
#  array([ 11.9   ,  20.3128,  28.7256,  37.1384,  45.5512,  53.964 ,
#          62.3768,  70.7896,  79.2024,  87.6152,  96.028 , 104.4408,
#         112.8536, 121.2664, 129.6792, 138.092 , 146.5048, 154.9176,
#         163.3304, 171.7432, 180.156 , 188.5688, 196.9816, 205.3944,
#         213.8072, 222.22  ]),
#  <a list of 25 Patch objects>)
