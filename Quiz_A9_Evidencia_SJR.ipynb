# %% [markdown]
# <a href="https://colab.research.google.com/github/salomonjose00/Proyecto/blob/main/Quiz_A9_Evidencia_SJR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Quiz A9 // Salomón José Ramos A01382587

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib as mlp
import seaborn as sns
import plotly.express as px

# %%
path= '/content/antropometria-dataset.csv'

# %%
df = pd.read_csv(path)
df
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 3       91526     4        9                 DISTRITO FEDERAL     1    10
# 4      210939     3       21                           PUEBLA     2    19
# ...       ...   ...      ...                              ...   ...   ...
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18637  301099     1       30  VERACRUZ DE IGNACIO DE LA LLAVE     1    86
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  \
# ...

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %% [markdown]
# P1
# En el regression simple, cadera=  b0  + b1*peso, ¿Cual seria valor de R-squared:?

# %%
import statsmodels.api as sm
from sklearn import linear_model

# %%
modelA= sm.OLS.from_formula('cadera~peso',
                            data=df
)
resultA = modelA.fit()
resultA.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 cadera   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.604
# Method:                 Least Squares   F-statistic:                 2.748e+04
# Date:                Wed, 19 Oct 2022   Prob (F-statistic):               0.00
# Time:                        03:47:34   Log-Likelihood:                -65165.
# No. Observations:               18032   AIC:                         1.303e+05
# Df Residuals:                   18030   BIC:                         1.304e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     57.4600      0.252    228.032      0.000      56.966      57.954
# ...

# %% [markdown]
# P2 ¿Cual seria coeficiente de correlación entre ' peso ' y ' cintura ' ?

# %%
df['peso'].corr(df['cintura'])
# Out:
# 0.79167686976069

# %%
df.corr(method='pearson')
# Out:
#                 folio      intp   entidad      sexo      edad     meses  \
# folio        1.000000 -0.017127  0.999979  0.010344  0.026894  0.014225
# intp        -0.017127  1.000000 -0.017200  0.046257 -0.636936 -0.006015
# entidad      0.999979 -0.017200  1.000000  0.010380  0.027015  0.014288
# sexo         0.010344  0.046257  0.010380  1.000000  0.039906 -0.000934
# edad         0.026894 -0.636936  0.027015  0.039906  1.000000  0.003416
# meses        0.014225 -0.006015  0.014288 -0.000934  0.003416  1.000000
# peso        -0.044368 -0.374168 -0.044406 -0.124461  0.317050 -0.004255
# ropa         0.011953 -0.007191  0.011915 -0.001227  0.018021  0.003584
# talla       -0.071853 -0.144495 -0.071862 -0.463303  0.021070  0.008326
# cintura     -0.026543 -0.421887 -0.026583  0.014791  0.478879  0.000214
# cadera      -0.032166 -0.321075 -0.032198  0.169966  0.340062  0.000300
# sistol       0.003985 -0.340492  0.004068 -0.083550  0.535218  0.009473
# ...

# %% [markdown]
# P3 En el regression simple, diastol=  b0  + b1*sistol, ¿Cual seria valor de Durbin-Watson:?

# %%
#alternative 
#cadera = peso*b1 + b0

model_ols = sm.OLS.from_formula("diastol ~ sistol", data=df)
result = model_ols.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                diastol   R-squared:                       0.439
# Model:                            OLS   Adj. R-squared:                  0.439
# Method:                 Least Squares   F-statistic:                 1.409e+04
# Date:                Wed, 19 Oct 2022   Prob (F-statistic):               0.00
# Time:                        04:37:05   Log-Likelihood:                -64272.
# No. Observations:               18032   AIC:                         1.285e+05
# Df Residuals:                   18030   BIC:                         1.286e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     23.9991      0.440     54.564      0.000      23.137      24.861
# ...

# %% [markdown]
# P4 En el regression, diastol = b0+ b1*sistol + b2*edad + b3*peso + b4*cintura ¿Cual seria valor de b0?

# %%
modelB= sm.OLS.from_formula('diastol~sistol + edad + peso + cintura', data=df)
resultB=modelB.fit()
resultB.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                diastol   R-squared:                       0.458
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     3812.
# Date:                Wed, 19 Oct 2022   Prob (F-statistic):               0.00
# Time:                        04:30:43   Log-Likelihood:                -63952.
# No. Observations:               18032   AIC:                         1.279e+05
# Df Residuals:                   18027   BIC:                         1.280e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     20.3297      0.520     39.089      0.000      19.310      21.349
# ...

# %%
df = df.dropna()
df
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 3       91526     4        9                 DISTRITO FEDERAL     1    10
# 4      210939     3       21                           PUEBLA     2    19
# ...       ...   ...      ...                              ...   ...   ...
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18637  301099     1       30  VERACRUZ DE IGNACIO DE LA LLAVE     1    86
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  \
# ...

# %% [markdown]
# P5 En el regression simple, diastol=  b0  + b1*sistol, ¿Cual seria valor de median de los residuos:?

# %%
model = sm.OLS.from_formula("diastol ~ sistol", data=df)
answ = model.fit()

# %%
answ.fittedvalues
# Out:
# 0         51.514707
# 1         54.451156
# 2         54.668671
# 3         54.886186
# 4         55.321215
#             ...
# 18635    120.140605
# 18636    120.684392
# 18637    124.055870
# 18638    126.231017
# 18639    128.406165
# Length: 18032, dtype: float64

# %%
answ.fittedvalues.median()
# Out:
# 75.22381291082681

# %%
answ.resid.median()
# Out:
# 0.011363868221820894
